# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import json
import requests
import time

# %%
url = 'https://datacatalog.cookcountyil.gov/resource/gpu3-5dfh.json'

# %%
res = requests.get(url)

# %%
res.headers
# Out:
# {'Server': 'nginx', 'Date': 'Thu, 20 Apr 2023 13:14:14 GMT', 'Content-Type': 'application/json;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*', 'ETag': '"Y2hhcmxpZS44MzYxMF8xXzI3X2Y3MldDa1pkNG9KdDlNc3dYbGhZVjdsY1BB---gzipxZOVCKB4mh42tWkS8f95LDZmm7Y--gzip--gzip"', 'X-SODA2-Fields': '["case_id","case_participant_id","received_date","offense_category","diversion_program","referral_date","diversion_count","primary_charge_offense_title","statute","race","gender","diversion_result","diversion_closed_date"]', 'X-SODA2-Types': '["number","number","floating_timestamp","text","text","floating_timestamp","number","text","text","text","text","text","floating_timestamp"]', 'X-SODA2-Data-Out-Of-Date': 'false', 'X-SODA2-Truth-Last-Modified': 'Wed, 05 Apr 2023 21:42:04 GMT', 'X-SODA2-Secondary-Last-Modified': 'Wed, 05 Apr 2023 21:42:04 GMT', 'Last-Modified': 'Wed, 05 Apr 2023 21:42:04 GMT', 'Vary': 'Accept-Encoding', 'Content-Encoding': 
# ...

# %%
res.headers['X-SODA2-Fields']
# Out:
# '["case_id","case_participant_id","received_date","offense_category","diversion_program","referral_date","diversion_count","primary_charge_offense_title","statute","race","gender","diversion_result","diversion_closed_date"]'

# %%
res = requests.get('https://datacatalog.cookcountyil.gov/resource/gpu3-5dfh.json?$limit=50000&$offset=0&')

# %%
div = pd.read_json('https://datacatalog.cookcountyil.gov/resource/gpu3-5dfh.json?$limit=30000&$offset=0&')

# %% [raw]
# The Diversion dataset contains information on defendants who receive a referral to a diversion program, including the type of program and date of referral; each row is a program to which a defendant has been referred.

# %%
disp = pd.read_json('https://datacatalog.cookcountyil.gov/resource/apwk-dzx8.json?$limit=1000000&')

# %% [raw]
# The disposition data presented in this data reflects the culmination of the fact-finding process that leads to the resolution of a case. Each row represents a charge that has been disposed of.

# %%
disp = []
disp_url = 'https://datacatalog.cookcountyil.gov/resource/apwk-dzx8.json'

for _ in range(20):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        disp.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
disp = pd.concat(disp,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %% [raw]
# The sentencing data presented in this report reflects the judgment imposed by the court on people that have been found guilty. Each row represents a charge that has been sentenced.

# %%
sent = []
sent_url = 'https://datacatalog.cookcountyil.gov/resource/tg8v-tm6u.json'

for _ in range(7):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        sent.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
sent = pd.concat(sent,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %% [raw]
# The Initiation results data presented here reflects all of the arrests that came through the door of the State's Attorneys Office (SAO). An initiation is how an arrest turns into a “case” in the courts. Most cases are initiated through a process known as felony review, in which SAO attorneys make a decision whether or not to prosecute. Cases may also be indicted by a grand jury or, in narcotics cases, filed directly by law enforcement (labeled "BOND SET (Narcotics)" in this data). Included in this data set are the defendant counts by initiation and year. This data includes felony cases handled by the Criminal, Narcotics, and Special Prosecution Bureaus. It does not include information about cases processed through the Juvenile Justice and Civil Actions Bureaus.

# %%
init = []
init_url = 'https://datacatalog.cookcountyil.gov/resource/7mck-ehwz.json'

for _ in range(24):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        init.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
init = pd.concat(init,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
intake = []
intake_url = 'https://datacatalog.cookcountyil.gov/resource/3k7z-hchi.json'

for _ in range(12):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        intake.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
intake = pd.concat(intake,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
# set topic
topic = 'HDBHR'

# set up list for outputs 
output = []

# find what data is available
res = requests.get(f'https://chicagohealthatlas.org/api/v1/coverage/{topic}')

# iterate over available data for topic
for i in range(len(res.json()['coverages']['place'])):
    
    # available population groups
    pop = res.json()['coverages']['place'][i]['population']

    # available time periods
    period = res.json()['coverages']['place'][i]['period']

    # api request for topic, pop, and period 
    url = f'https://chicagohealthatlas.org/api/v1/data/?topic={topic}&population={pop}&period={period}'

    # append results
    output.append(pd.DataFrame.from_dict(requests.get(url).json()['results']))

# concatenate into single df
HDBHR = pd.concat(output,axis=0)
HDBHR
# Out:
#             se        g      l      a  p     d      v
# 0    10.586735    60601    zip  HDBHR     2017   85.4
# 1   122.270408    60602    zip  HDBHR     2017  400.5
# 2   493.877551    60603    zip  HDBHR     2017  990.3
# 3   178.163265    60604    zip  HDBHR     2017  674.2
# 4   132.423469    60606    zip  HDBHR     2017  488.3
# ..         ...      ...    ...    ... ..   ...    ...
# 0     1.862245  1714000  place  HDBHR  S  2014   96.3
# 0     1.811224  1714000  place  HDBHR  S  2013   90.9
# 0     1.938776  1714000  place  HDBHR  S  2012  103.3
# 0     1.887755  1714000  place  HDBHR  S  2011   98.1
# 0     1.938776  1714000  place  HDBHR  S  2010  102.8
#
# [488 rows x 7 columns]

# %%
# set of topics
topics = ['HDBHR','HDSZR','HCSBHP','HDDRR','YRDEP','YRSUP'
         'HDMDR','MEODR','HCSSPDP']

# iterate over topics
for topic in topics:

    # set up list for outputs 
    output = []

    # find what data is available
    res = requests.get(f'https://chicagohealthatlas.org/api/v1/coverage/{topic}')

    # iterate over available data for topic
    for i in range(len(res.json()['coverages']['place'])):
        
        try:
            # available population groups
            pop = res.json()['coverages']['place'][i]['population']

            # available time periods
            period = res.json()['coverages']['place'][i]['period']

            # api request for topic, pop, and period 
            url = f'https://chicagohealthatlas.org/api/v1/data/?topic={topic}&population={pop}&period={period}'
    
            # append results
            output.append(pd.DataFrame.from_dict(requests.get(url).json()['results']))
            
            print((topic,pop,period))
        
            time.sleep(1)
        except:
            pass
        
    # concatenate into single df for topic and save as csv
    pd.concat(output,axis=0).to_csv(f'{topic}.csv',index=False)
# Out:
# ('HDBHR', '', '2017')
# ('HDBHR', '', '2016')
# ('HDBHR', '', '2014')
# ('HDBHR', '', '2013')
# ('HDBHR', '', '2012')
# ('HDBHR', '', '2011')
# ('HDBHR', '', '2010')
# ('HDBHR', 'F', '2017')
# ('HDBHR', 'F', '2016')
# ('HDBHR', 'F', '2014')
# ('HDBHR', 'F', '2013')
# ('HDBHR', 'F', '2012')
# ('HDBHR', 'F', '2011')
# ('HDBHR', 'F', '2010')
# ('HDBHR', 'M', '2017')
# ('HDBHR', 'M', '2016')
# ('HDBHR', 'M', '2014')
# ('HDBHR', 'M', '2013')
# ('HDBHR', 'M', '2012')
# ('HDBHR', 'M', '2011')
# ('HDBHR', 'M', '2010')
# ('HDBHR', 'W', '2017')
# ('HDBHR', 'W', '2016')
# ('HDBHR', 'W', '2014')
# ('HDBHR', 'W', '2013')
# ('HDBHR', 'W', '2012')
# ('HDBHR', 'W', '2011')
# ('HDBHR', 'W', '2010')
# ('HDBHR', 'B', '2017')
# ('HDBHR', 'B', '2016')
# ('HDBHR', 'B', '2014')
# ('HDBHR', 'B', '2013')
# ('HDBHR', 'B', '2012')
# ('HDBHR', 'B', '2011')
# ('HDBHR', 'B', '2010')
# ('HDBHR', 'AP', '2017')
# ('HDBHR', 'AP', '2016')
# ('HDBHR', 'AP', '2014')
# ('HDBHR', 'AP', '2013')
# ('HDBHR', 'AP', '2012')
# ...

# %%
res = requests.get('https://data.cityofchicago.org/resource/vcv6-95ym.json')
clinics = pd.DataFrame(res.json())
clinics.to_csv('clinics.csv',index=False)

# %%
output = []
crime_url = 'https://data.cityofchicago.org/resource/crimes.json'

for _ in range(20):
    offset = 0
    res = requests.get(f'{crime_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        output.append(pd.DataFrame(res.json()))
        offset += 50_000
        time.sleep(1)
    except:
        pass
crime = pd.concat(output,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
div.to_csv('data/div.csv',index=False)
disp.to_csv('data/disp.csv',index=False)
sent.to_csv('data/sent.csv',index=False)
init.to_csv('data/init.csv',index=False)
intake.to_csv('data/intake.csv',index=False)

# %%
HDBHR.to_csv('data/hdbhr.csv',index=False)

# %%
crime.to_csv('crime.csv',index=False)

# %%
import pandas as pd
from sqlalchemy import inspect, create_engine

# %%
url = 'localhost'
port = 5432
user = 'postgres'
pswd = 'postgres'
db = 'project4'

# %%
connection_string = f'postgresql://{user}:{pswd}@{url}:{port}/{db}'

engine = create_engine(connection_string,
                       echo=False)        

engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/project4)

# %%
insp = inspect(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
insp.get_table_names()

# %%
conn = engine.connect()

# %%
pd.DataFrame(insp.get_columns('animals'))

# %%
animals = pd.DataFrame(conn.execute("SELECT * FROM animals"))
animals.head()

# %%
div = pd.read_csv('data/div.csv')
div.head()
# Out:
#         case_id  case_participant_id            received_date  \
# 0  698837098171         405118970904  2011-01-01T00:00:00.000
# 1  698837098171         405118970904  2011-01-01T00:00:00.000
# 2  698842998260         405124350189  2011-01-02T00:00:00.000
# 3  698850507464         405130912917  2011-01-03T00:00:00.000
# 4  698850507464         405130966710  2011-01-03T00:00:00.000
#
#   offense_category diversion_program            referral_date  \
# 0     Retail Theft                DS  2013-06-17T00:00:00.000
# 1     Retail Theft                VC  2011-08-11T00:00:00.000
# 2     Retail Theft               MHC  2012-09-14T00:00:00.000
# 3        Narcotics               MHC  2018-07-27T00:00:00.000
# 4        Narcotics               MHC  2018-07-27T00:00:00.000
#
#    diversion_count                       primary_charge_offense_title  \
# 0                2                                       RETAIL THEFT
# 1                1                                       RETAIL THEFT
# ...

# %%
disp = pd.read_csv('data/disp.csv')
disp.head()
# Out:
# C:\Users\HyeOL\AppData\Local\Temp\ipykernel_17456\4128039102.py:1: DtypeWarning: Columns (10,11,14,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp = pd.read_csv('data/disp.csv')
#         case_id  case_participant_id            received_date  \
# 0  273501301122         100145238029  1984-08-15T00:00:00.000
# 1  273501301122         100145238029  1984-08-15T00:00:00.000
# 2  273501301122         100145238029  1984-08-15T00:00:00.000
# 3  273501301122         100145238029  1984-08-15T00:00:00.000
# 4  273501301122         100145238029  1984-08-15T00:00:00.000
#
#     offense_category  primary_charge    charge_id  charge_version_id  \
# 0  PROMIS Conversion           False  69237863947        57646182866
# 1  PROMIS Conversion           False  69237932864        46713646169
# 2  PROMIS Conversion           False  69238001780        48705084426
# 3  PROMIS Conversion           False  69238070697        48705269641
# ...

# %%
sent = pd.read_csv('data/sent.csv')
sent.head()
# Out:
# C:\Users\HyeOL\AppData\Local\Temp\ipykernel_17456\3585100491.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sent = pd.read_csv('data/sent.csv')
#         case_id  case_participant_id            received_date  \
# 0  273501301122         100145238029  1984-08-15T00:00:00.000
# 1  273501301122         100145238029  1984-08-15T00:00:00.000
# 2  273501301122         100145238029  1984-08-15T00:00:00.000
# 3  273501301122         100145238029  1984-08-15T00:00:00.000
# 4  273501301122         100145238029  1984-08-15T00:00:00.000
#
#     offense_category  primary_charge    charge_id  charge_version_id  \
# 0  PROMIS Conversion           False  69237863947        57646182866
# 1  PROMIS Conversion           False  69237932864        46713646169
# 2  PROMIS Conversion           False  69238001780        48705084426
# 3  PROMIS Conversion           False  69238070697        48705269641
# ...

# %%
sent.shape
# Out:
# (350000, 33)

# %%
init = pd.read_csv('data/init.csv')
init.head()
# Out:
# C:\Users\HyeOL\AppData\Local\Temp\ipykernel_17456\3978207861.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   init = pd.read_csv('data/init.csv')
#         case_id  case_participant_id            received_date  \
# 0  273501301122         100145238029  1984-08-15T00:00:00.000
# 1  273501301122         100145238029  1984-08-15T00:00:00.000
# 2  273501301122         100145238029  1984-08-15T00:00:00.000
# 3  273501301122         100145238029  1984-08-15T00:00:00.000
# 4  273501301122         100145238029  1984-08-15T00:00:00.000
#
#     offense_category  primary_charge    charge_id  charge_version_id  \
# 0  PROMIS Conversion           False  69237863947        57646182866
# 1  PROMIS Conversion           False  69237932864        46713646169
# 2  PROMIS Conversion           False  69238001780        48705084426
# 3  PROMIS Conversion           False  69238070697        48705269641
# ...

# %%
init.shape
# Out:
# (1200000, 33)

# %%
intake = pd.read_csv('data/intake.csv')
intake.head()
# Out:
# C:\Users\HyeOL\AppData\Local\Temp\ipykernel_17456\1800018487.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   intake = pd.read_csv('data/intake.csv')
#         case_id  case_participant_id            received_date  \
# 0  273501301122         100145238029  1984-08-15T00:00:00.000
# 1  273501301122         100145238029  1984-08-15T00:00:00.000
# 2  273501301122         100145238029  1984-08-15T00:00:00.000
# 3  273501301122         100145238029  1984-08-15T00:00:00.000
# 4  273501301122         100145238029  1984-08-15T00:00:00.000
#
#     offense_category  primary_charge    charge_id  charge_version_id  \
# 0  PROMIS Conversion           False  69237863947        57646182866
# 1  PROMIS Conversion           False  69237932864        46713646169
# 2  PROMIS Conversion           False  69238001780        48705084426
# 3  PROMIS Conversion           False  69238070697        48705269641
# ...

# %%
hdbhr = pd.read_csv('data/hdbhr.csv')
hdbhr.head()
# Out:
#            se      g    l      a    p     d      v
# 0   10.586735  60601  zip  HDBHR  NaN  2017   85.4
# 1  122.270408  60602  zip  HDBHR  NaN  2017  400.5
# 2  493.877551  60603  zip  HDBHR  NaN  2017  990.3
# 3  178.163265  60604  zip  HDBHR  NaN  2017  674.2
# 4  132.423469  60606  zip  HDBHR  NaN  2017  488.3

# %%
pip install geopandas
# Out:
# ...
#      ---------------------------------------- 1.1/1.1 MB 9.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.1/5.1 MB 21.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.4/1.4 MB 21.9 MB/s eta 0:00:00
# ...
#      --------------------------------------- 21.9/21.9 MB 19.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install descartes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
# make sure all files from Major Streets are in same directory
# will make this cleaner later on
streets = gpd.read_file('C:\Users\HyeOL\OneDrive\Documents\GitHub\project_4\data\Major_Streets\Major_Streets.shp')

fig, ax = plt.subplots(figsize = (15,15))
streets.plot(ax = ax)
# Out:
#   Cell In[19], line 3
#     streets = gpd.read_file('C:\Users\HyeOL\OneDrive\Documents\GitHub\project_4\data\Major_Streets\Major_Streets.shp')
#                                                                                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
