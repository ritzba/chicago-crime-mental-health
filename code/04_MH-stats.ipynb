# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
treat = pd.read_pickle('../data/HCSBHP.pkl', compression='zip')

# %%
psych_distress = pd.read_pickle('../data/HCSSPDP.pkl', compression='zip')

# %%
psych_distress.head()
# Out:
#          se           g             l        a p          d          v
# 0  1.493571  1714000-35  neighborhood  HCSSPDP    2021-2022   3.120683
# 1  9.531264  1714000-37  neighborhood  HCSSPDP    2021-2022  27.763914
# 2  4.983833  1714000-38  neighborhood  HCSSPDP    2021-2022  13.669206
# 3  2.875402  1714000-39  neighborhood  HCSSPDP    2021-2022   6.371035
# 4  3.309448   1714000-4  neighborhood  HCSSPDP    2021-2022  10.243905

# %%
distress = pd.read_pickle('../data/HCSSPDP.pkl', compression='zip')

# %%
opioid = pd.read_pickle('../data/MEODR.pkl', compression='zip')
# Out:
# 1714000       132
# 1714000-4       2
# 1714000-22      2
# 1714000-77      2
# 1714000-72      2
# 1714000-6       2
# 1714000-59      2
# 1714000-56      2
# 1714000-40      2
# 1714000-8       2
# 1714000-3       2
# 1714000-24      2
# 1714000-51      2
# 1714000-1       2
# 1714000-42      2
# 1714000-17      2
# 1714000-12      2
# 1714000-11      2
# 1714000-41      2
# 1714000-67      1
# 1714000-54      1
# 1714000-53      1
# 1714000-47      1
# 1714000-33      1
# 1714000-30      1
# 1714000-28      1
# 1714000-21      1
# 1714000-36      1
# 1714000-23      1
# 1714000-73      1
# 1714000-20      1
# 1714000-65      1
# 1714000-63      1
# 1714000-15      1
# 1714000-16      1
# 1714000-50      1
# 1714000-5       1
# 1714000-2       1
# 1714000-26      1
# 1714000-7       1
# Name: g, dtype: int64

# %%
HCSSPDP = pd.read_pickle('../data/HCSSPDP.pkl', compression='zip')

# %%
HCSSPDP
# Out:
#           se           g             l        a  p          d          v
# 0   1.493571  1714000-35  neighborhood  HCSSPDP     2021-2022   3.120683
# 1   9.531264  1714000-37  neighborhood  HCSSPDP     2021-2022  27.763914
# 2   4.983833  1714000-38  neighborhood  HCSSPDP     2021-2022  13.669206
# 3   2.875402  1714000-39  neighborhood  HCSSPDP     2021-2022   6.371035
# 4   3.309448   1714000-4  neighborhood  HCSSPDP     2021-2022  10.243905
# ..       ...         ...           ...      ... ..        ...        ...
# 0   0.763609     1714000         place  HCSSPDP  Z       2020   6.180849
# 0   0.841837     1714000         place  HCSSPDP  Z       2018   3.600000
# 0   0.484694     1714000         place  HCSSPDP  Z       2017   1.600000
# 0   0.663265     1714000         place  HCSSPDP  Z       2016   2.300000
# 0   0.561224     1714000         place  HCSSPDP  Z       2015   1.600000
#
# [232 rows x 7 columns]

# %%
HDBHR = pd.read_pickle('../data/HDBHR.pkl', compression='zip')

# %%
HDBHR['g']
# Out:
#           se        g      l      a  p     d      v
# 58  0.816327  1714000  place  HDBHR     2017  173.3
# 58  0.816327  1714000  place  HDBHR     2016  174.6
# 57  0.816327  1714000  place  HDBHR     2014  176.3
# 58  0.790816  1714000  place  HDBHR     2013  161.7
# 58  0.867347  1714000  place  HDBHR     2012  197.9
# ..       ...      ...    ...    ... ..   ...    ...
# 0   1.862245  1714000  place  HDBHR  S  2014   96.3
# 0   1.811224  1714000  place  HDBHR  S  2013   90.9
# 0   1.938776  1714000  place  HDBHR  S  2012  103.3
# 0   1.887755  1714000  place  HDBHR  S  2011   98.1
# 0   1.938776  1714000  place  HDBHR  S  2010  102.8
#
# [84 rows x 7 columns]
