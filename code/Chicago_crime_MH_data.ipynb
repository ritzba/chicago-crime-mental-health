# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import json
import requests
import time

# %%
import time

# %%
div = pd.read_json('https://datacatalog.cookcountyil.gov/resource/gpu3-5dfh.json?$limit=30000&$offset=0&')
# Out:
#             case_id  case_participant_id            received_date  \
# 0      698837098171         405118970904  2011-01-01T00:00:00.000
# 1      698837098171         405118970904  2011-01-01T00:00:00.000
# 2      698842998260         405124350189  2011-01-02T00:00:00.000
# 3      698850507464         405130912917  2011-01-03T00:00:00.000
# 4      698850507464         405130966710  2011-01-03T00:00:00.000
# ...             ...                  ...                      ...
# 26365  830597346297         532560799944  2023-03-16T00:00:00.000
# 26366  830597614483         532561122701  2023-03-16T00:00:00.000
# 26367  830634892317         532600014933  2023-03-17T00:00:00.000
# 26368  830670024665         532640036815  2023-03-20T00:00:00.000
# 26369  830747798563         532720995057  2023-03-23T00:00:00.000
#
#                          offense_category diversion_program  \
# 0                            Retail Theft                DS
# 1                            Retail Theft                VC
# 2                            Retail Theft               MHC
# 3                               Narcotics               MHC
# 4                               Narcotics               MHC
# ...                                   ...               ...
# 26365                           Narcotics              DDPP
# 26366                           Narcotics              DDPP
# 26367         Criminal Damage to Property               BR9
# 26368                           Narcotics              DDPP
# 26369  Possession of Stolen Motor Vehicle              RJCC
#
#                  referral_date  diversion_count  \
# 0      2013-06-17T00:00:00.000                2
# 1      2011-08-11T00:00:00.000                1
# 2      2012-09-14T00:00:00.000                1
# 3      2018-07-27T00:00:00.000                1
# 4      2018-07-27T00:00:00.000                1
# ...                        ...              ...
# 26365  2023-03-14T00:00:00.000                1
# 26366  2023-03-15T00:00:00.000                1
# 26367  2023-03-27T00:00:00.000                1
# 26368  2022-11-21T00:00:00.000                1
# 26369  2023-04-05T00:00:00.000                1
#
#                             primary_charge_offense_title  \
# 0                                           RETAIL THEFT
# 1                                           RETAIL THEFT
# 2                                           RETAIL THEFT
# 3      [POSSESSION OF CONTROLLED SUBSTANCE WITH INTEN...
# 4                   POSSESSION OF A CONTROLLED SUBSTANCE
# ...                                                  ...
# 26365               POSSESSION OF A CONTROLLED SUBSTANCE
# 26366               POSSESSION OF A CONTROLLED SUBSTANCE
# 26367                        CRIMINAL DAMAGE TO PROPERTY
# 26368               POSSESSION OF A CONTROLLED SUBSTANCE
# 26369               POSSESSION OF A STOLEN MOTOR VEHICLE
#
#                       statute     race   gender diversion_result  \
# 0         720 ILCS 5/16A-3(a)    Black     Male        Graduated
# 1         720 ILCS 5/16A-3(a)    Black     Male              NaN
# 2         720 ILCS 5/16A-3(a)    Black     Male           Failed
# 3      720 ILCS 570/401(d)(i)    Black   Female              NaN
# 4         720 ILCS 570/402(c)    White     Male              NaN
# ...                       ...      ...      ...              ...
# 26365     720 ILCS 570/402(c)    White   Female              NaN
# 26366     720 ILCS 570/402(c)    White     Male              NaN
# 26367   720 ILCS 5/21-1(a)(1)  Unknown  Unknown              NaN
# 26368     720 ILCS 570/402(c)   Latinx   Female           Failed
# 26369  625 ILCS 5/4-103(a)(1)    Black     Male              NaN
#
#          diversion_closed_date
# 0      2013-06-17T00:00:00.000
# 1                          NaN
# 2      2012-09-14T00:00:00.000
# 3                          NaN
# 4                          NaN
# ...                        ...
# 26365                      NaN
# 26366                      NaN
# 26367                      NaN
# 26368  2023-03-16T00:00:00.000
# 26369                      NaN
#
# [26370 rows x 13 columns]

# %%
disp = []
disp_url = 'https://datacatalog.cookcountyil.gov/resource/apwk-dzx8.json'

for _ in range(20):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        disp.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
disp = pd.concat(disp,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
sent = []
sent_url = 'https://datacatalog.cookcountyil.gov/resource/tg8v-tm6u.json'

for _ in range(7):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        sent.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
sent = pd.concat(sent,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
init = []
init_url = 'https://datacatalog.cookcountyil.gov/resource/7mck-ehwz.json'

for _ in range(24):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        init.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
init = pd.concat(init,axis = 0)

# %%
intake = []
intake_url = 'https://datacatalog.cookcountyil.gov/resource/3k7z-hchi.json'

for _ in range(12):
    offset = 0
    res = requests.get(f'{disp_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        cases = pd.DataFrame(res.json())
        intake.append(cases)
        offset += 50_000
        time.sleep(1)
    except:
        pass
intake = pd.concat(intake,axis = 0)

# %%
div.to_csv('div.csv',index=False)
intake.to_csv('intake.csv',index=False)
init.to_csv('init.csv',index=False)
sent.to_csv('sent.csv',index=False)
disp.to_csv('disp.csv',index=False)

# %%
https://chicagohealthatlas.org/indicators/HDDR?category=behavioral-health

# %%
res = requests.get('https://chicagohealthatlas.org/api/v1/data/?topic="HDBH"&')

# %%
res.json()
# Out:
# {'detail': 'Error: Too many results. You must filter by either topic + population + period, or layer + geography.'}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import json
import requests
import time

# %%
# set of topics
topics = ['HDBHR','HDSZR','HCSBHP','HDDRR','YRDEP','YRSUP'
         'HDMDR','MEODR','HCSSPDP']

# iterate over topics
for topic in topics:

    # set up list for outputs 
    output = []

    # find what data is available
    res = requests.get(f'https://chicagohealthatlas.org/api/v1/coverage/{topic}')

    # iterate over available data for topic
    for i in range(len(res.json()['coverages']['place'])):
        
        try:
            # available population groups
            pop = res.json()['coverages']['place'][i]['population']

            # available time periods
            period = res.json()['coverages']['place'][i]['period']

            # api request for topic, pop, and period 
            url = f'https://chicagohealthatlas.org/api/v1/data/?topic={topic}&population={pop}&period={period}'
    
            # append results
            output.append(pd.DataFrame.from_dict(requests.get(url).json()['results']))
            
            print((topic,pop,period))
        
            time.sleep(1)
        except:
            pass
        
    # concatenate into single df for topic and save as csv
    pd.concat(output,axis=0).to_csv(f'{topic}.csv',index=False)
# Out:
# ('HDBHR', '', '2017')
# ('HDBHR', '', '2016')
# ('HDBHR', '', '2014')
# ('HDBHR', '', '2013')
# ('HDBHR', '', '2012')
# ('HDBHR', '', '2011')
# ('HDBHR', '', '2010')
# ('HDBHR', 'F', '2017')
# ('HDBHR', 'F', '2016')
# ('HDBHR', 'F', '2014')
# ('HDBHR', 'F', '2013')
# ('HDBHR', 'F', '2012')
# ('HDBHR', 'F', '2011')
# ('HDBHR', 'F', '2010')
# ('HDBHR', 'M', '2017')
# ('HDBHR', 'M', '2016')
# ('HDBHR', 'M', '2014')
# ('HDBHR', 'M', '2013')
# ('HDBHR', 'M', '2012')
# ('HDBHR', 'M', '2011')
# ('HDBHR', 'M', '2010')
# ('HDBHR', 'W', '2017')
# ('HDBHR', 'W', '2016')
# ('HDBHR', 'W', '2014')
# ('HDBHR', 'W', '2013')
# ('HDBHR', 'W', '2012')
# ('HDBHR', 'W', '2011')
# ('HDBHR', 'W', '2010')
# ('HDBHR', 'B', '2017')
# ('HDBHR', 'B', '2016')
# ('HDBHR', 'B', '2014')
# ('HDBHR', 'B', '2013')
# ('HDBHR', 'B', '2012')
# ('HDBHR', 'B', '2011')
# ('HDBHR', 'B', '2010')
# ('HDBHR', 'AP', '2017')
# ('HDBHR', 'AP', '2016')
# ('HDBHR', 'AP', '2014')
# ('HDBHR', 'AP', '2013')
# ('HDBHR', 'AP', '2012')
# ('HDBHR', 'AP', '2011')
# ('HDBHR', 'AP', '2010')
# ('HDBHR', 'H', '2017')
# ('HDBHR', 'H', '2016')
# ('HDBHR', 'H', '2014')
# ('HDBHR', 'H', '2013')
# ('HDBHR', 'H', '2012')
# ('HDBHR', 'H', '2011')
# ('HDBHR', 'H', '2010')
# ('HDBHR', 'C', '2017')
# ('HDBHR', 'C', '2016')
# ('HDBHR', 'C', '2014')
# ('HDBHR', 'C', '2013')
# ('HDBHR', 'C', '2012')
# ('HDBHR', 'C', '2011')
# ('HDBHR', 'C', '2010')
# ('HDBHR', 'G', '2017')
# ('HDBHR', 'G', '2016')
# ('HDBHR', 'G', '2014')
# ('HDBHR', 'G', '2013')
# ('HDBHR', 'G', '2012')
# ('HDBHR', 'G', '2011')
# ('HDBHR', 'G', '2010')
# ('HDBHR', 'K', '2017')
# ('HDBHR', 'K', '2016')
# ('HDBHR', 'K', '2014')
# ('HDBHR', 'K', '2013')
# ('HDBHR', 'K', '2012')
# ('HDBHR', 'K', '2011')
# ('HDBHR', 'K', '2010')
# ('HDBHR', 'N', '2017')
# ('HDBHR', 'N', '2016')
# ('HDBHR', 'N', '2014')
# ('HDBHR', 'N', '2013')
# ('HDBHR', 'N', '2012')
# ('HDBHR', 'N', '2011')
# ('HDBHR', 'N', '2010')
# ('HDBHR', 'S', '2017')
# ('HDBHR', 'S', '2016')
# ('HDBHR', 'S', '2014')
# ('HDBHR', 'S', '2013')
# ('HDBHR', 'S', '2012')
# ('HDBHR', 'S', '2011')
# ('HDBHR', 'S', '2010')
# ('HDSZR', '', '2017')
# ('HDSZR', '', '2016')
# ('HDSZR', '', '2014')
# ('HDSZR', '', '2013')
# ('HDSZR', '', '2012')
# ('HDSZR', '', '2011')
# ('HDSZR', '', '2010')
# ('HDSZR', 'F', '2017')
# ('HDSZR', 'F', '2016')
# ('HDSZR', 'F', '2014')
# ('HDSZR', 'F', '2013')
# ('HDSZR', 'F', '2012')
# ('HDSZR', 'F', '2011')
# ('HDSZR', 'F', '2010')
# ('HDSZR', 'M', '2017')
# ('HDSZR', 'M', '2016')
# ('HDSZR', 'M', '2014')
# ('HDSZR', 'M', '2013')
# ('HDSZR', 'M', '2012')
# ('HDSZR', 'M', '2011')
# ('HDSZR', 'M', '2010')
# ('HDSZR', 'W', '2017')
# ('HDSZR', 'W', '2016')
# ('HDSZR', 'W', '2014')
# ('HDSZR', 'W', '2013')
# ('HDSZR', 'W', '2012')
# ('HDSZR', 'W', '2011')
# ('HDSZR', 'W', '2010')
# ('HDSZR', 'B', '2017')
# ('HDSZR', 'B', '2016')
# ('HDSZR', 'B', '2014')
# ('HDSZR', 'B', '2013')
# ('HDSZR', 'B', '2012')
# ('HDSZR', 'B', '2011')
# ('HDSZR', 'B', '2010')
# ('HDSZR', 'AP', '2017')
# ('HDSZR', 'AP', '2016')
# ('HDSZR', 'AP', '2014')
# ('HDSZR', 'AP', '2013')
# ('HDSZR', 'AP', '2012')
# ('HDSZR', 'AP', '2011')
# ('HDSZR', 'AP', '2010')
# ('HDSZR', 'H', '2017')
# ('HDSZR', 'H', '2016')
# ('HDSZR', 'H', '2014')
# ('HDSZR', 'H', '2013')
# ('HDSZR', 'H', '2012')
# ('HDSZR', 'H', '2011')
# ('HDSZR', 'H', '2010')
# ('HDSZR', 'C', '2017')
# ('HDSZR', 'C', '2016')
# ('HDSZR', 'C', '2014')
# ('HDSZR', 'C', '2013')
# ('HDSZR', 'C', '2012')
# ('HDSZR', 'C', '2011')
# ('HDSZR', 'C', '2010')
# ('HDSZR', 'G', '2017')
# ('HDSZR', 'G', '2016')
# ('HDSZR', 'G', '2014')
# ('HDSZR', 'G', '2013')
# ('HDSZR', 'G', '2012')
# ('HDSZR', 'G', '2011')
# ('HDSZR', 'G', '2010')
# ('HDSZR', 'K', '2017')
# ('HDSZR', 'K', '2016')
# ('HDSZR', 'K', '2014')
# ('HDSZR', 'K', '2013')
# ('HDSZR', 'K', '2012')
# ('HDSZR', 'K', '2011')
# ('HDSZR', 'K', '2010')
# ('HDSZR', 'N', '2017')
# ('HDSZR', 'N', '2016')
# ('HDSZR', 'N', '2014')
# ('HDSZR', 'N', '2013')
# ('HDSZR', 'N', '2012')
# ('HDSZR', 'N', '2011')
# ('HDSZR', 'N', '2010')
# ('HDSZR', 'S', '2017')
# ('HDSZR', 'S', '2016')
# ('HDSZR', 'S', '2014')
# ('HDSZR', 'S', '2013')
# ('HDSZR', 'S', '2012')
# ('HDSZR', 'S', '2011')
# ('HDSZR', 'S', '2010')
# ('HCSBHP', '', '2021-2022')
# ('HCSBHP', '', '2022')
# ('HCSBHP', '', '2020-2021')
# ('HCSBHP', '', '2021')
# ('HCSBHP', '', '2020')
# ('HCSBHP', '', '2018')
# ('HCSBHP', '', '2017')
# ('HCSBHP', '', '2016')
# ('HCSBHP', '', '2015')
# ('HCSBHP', '', '2014')
# ('HCSBHP', 'F', '2022')
# ('HCSBHP', 'F', '2021')
# ('HCSBHP', 'F', '2020')
# ('HCSBHP', 'F', '2018')
# ('HCSBHP', 'F', '2017')
# ('HCSBHP', 'F', '2016')
# ('HCSBHP', 'F', '2015')
# ('HCSBHP', 'F', '2014')
# ('HCSBHP', 'M', '2022')
# ('HCSBHP', 'M', '2021')
# ('HCSBHP', 'M', '2020')
# ('HCSBHP', 'M', '2018')
# ('HCSBHP', 'M', '2017')
# ('HCSBHP', 'M', '2016')
# ('HCSBHP', 'M', '2015')
# ('HCSBHP', 'M', '2014')
# ('HCSBHP', 'W', '2022')
# ('HCSBHP', 'W', '2021')
# ('HCSBHP', 'W', '2020')
# ('HCSBHP', 'W', '2018')
# ('HCSBHP', 'W', '2017')
# ('HCSBHP', 'W', '2016')
# ('HCSBHP', 'W', '2015')
# ('HCSBHP', 'W', '2014')
# ('HCSBHP', 'B', '2022')
# ('HCSBHP', 'B', '2021')
# ('HCSBHP', 'B', '2020')
# ('HCSBHP', 'B', '2018')
# ('HCSBHP', 'B', '2017')
# ('HCSBHP', 'B', '2016')
# ('HCSBHP', 'B', '2015')
# ('HCSBHP', 'B', '2014')
# ('HCSBHP', 'A', '2022')
# ('HCSBHP', 'AP', '2020')
# ('HCSBHP', 'AP', '2014')
# ('HCSBHP', 'H', '2022')
# ('HCSBHP', 'H', '2021')
# ('HCSBHP', 'H', '2020')
# ('HCSBHP', 'H', '2018')
# ('HCSBHP', 'H', '2017')
# ('HCSBHP', 'H', '2016')
# ('HCSBHP', 'H', '2015')
# ('HCSBHP', 'H', '2014')
# ('HCSBHP', 'GEN1', '2022')
# ('HCSBHP', 'TRA3', '2022')
# ('HCSBHP', 'G', '2022')
# ('HCSBHP', 'G', '2021')
# ('HCSBHP', 'G', '2020')
# ('HCSBHP', 'G', '2018')
# ('HCSBHP', 'G', '2017')
# ('HCSBHP', 'G', '2016')
# ('HCSBHP', 'G', '2015')
# ('HCSBHP', 'G', '2014')
# ('HCSBHP', 'K', '2022')
# ('HCSBHP', 'K', '2021')
# ('HCSBHP', 'K', '2020')
# ('HCSBHP', 'K', '2018')
# ('HCSBHP', 'K', '2017')
# ('HCSBHP', 'K', '2016')
# ('HCSBHP', 'K', '2015')
# ('HCSBHP', 'K', '2014')
# ('HCSBHP', 'N', '2022')
# ('HCSBHP', 'N', '2021')
# ('HCSBHP', 'N', '2020')
# ('HCSBHP', 'N', '2018')
# ('HCSBHP', 'N', '2017')
# ('HCSBHP', 'N', '2016')
# ('HCSBHP', 'N', '2015')
# ('HCSBHP', 'N', '2014')
# ('HCSBHP', 'S', '2022')
# ('HCSBHP', 'S', '2021')
# ('HCSBHP', 'S', '2020')
# ('HCSBHP', 'S', '2018')
# ('HCSBHP', 'S', '2017')
# ('HCSBHP', 'S', '2016')
# ('HCSBHP', 'S', '2015')
# ('HCSBHP', 'S', '2014')
# ('HCSBHP', 'E', '2022')
# ('HCSBHP', 'E', '2021')
# ('HCSBHP', 'E', '2020')
# ('HCSBHP', 'E', '2018')
# ('HCSBHP', 'E', '2017')
# ('HCSBHP', 'E', '2016')
# ('HCSBHP', 'E', '2015')
# ('HCSBHP', 'E', '2014')
# ('HCSBHP', 'L', '2022')
# ('HCSBHP', 'L', '2021')
# ('HCSBHP', 'L', '2020')
# ('HCSBHP', 'L', '2018')
# ('HCSBHP', 'L', '2017')
# ('HCSBHP', 'L', '2016')
# ('HCSBHP', 'L', '2015')
# ('HCSBHP', 'L', '2014')
# ('HCSBHP', 'R', '2022')
# ('HCSBHP', 'R', '2021')
# ('HCSBHP', 'R', '2020')
# ('HCSBHP', 'R', '2018')
# ('HCSBHP', 'R', '2017')
# ('HCSBHP', 'R', '2016')
# ('HCSBHP', 'R', '2015')
# ('HCSBHP', 'R', '2014')
# ('HCSBHP', 'U', '2022')
# ('HCSBHP', 'U', '2021')
# ('HCSBHP', 'U', '2020')
# ('HCSBHP', 'U', '2018')
# ('HCSBHP', 'U', '2017')
# ('HCSBHP', 'U', '2015')
# ('HCSBHP', 'U', '2014')
# ('HCSBHP', 'V', '2022')
# ('HCSBHP', 'V', '2021')
# ('HCSBHP', 'V', '2020')
# ('HCSBHP', 'V', '2018')
# ('HCSBHP', 'V', '2017')
# ('HCSBHP', 'V', '2015')
# ('HCSBHP', 'V', '2014')
# ('HCSBHP', 'Z', '2022')
# ('HCSBHP', 'Z', '2021')
# ('HCSBHP', 'Z', '2020')
# ('HCSBHP', 'Z', '2018')
# ('HCSBHP', 'Z', '2017')
# ('HCSBHP', 'Z', '2016')
# ('HCSBHP', 'Z', '2015')
# ('HDDRR', '', '2017')
# ('HDDRR', '', '2016')
# ('HDDRR', '', '2014')
# ('HDDRR', '', '2013')
# ('HDDRR', '', '2012')
# ('HDDRR', '', '2011')
# ('HDDRR', '', '2010')
# ('HDDRR', 'F', '2017')
# ('HDDRR', 'F', '2016')
# ('HDDRR', 'F', '2014')
# ('HDDRR', 'F', '2013')
# ('HDDRR', 'F', '2012')
# ('HDDRR', 'F', '2011')
# ('HDDRR', 'F', '2010')
# ('HDDRR', 'M', '2017')
# ('HDDRR', 'M', '2016')
# ('HDDRR', 'M', '2014')
# ('HDDRR', 'M', '2013')
# ('HDDRR', 'M', '2012')
# ('HDDRR', 'M', '2011')
# ('HDDRR', 'M', '2010')
# ('HDDRR', 'W', '2017')
# ('HDDRR', 'W', '2016')
# ('HDDRR', 'W', '2014')
# ('HDDRR', 'W', '2013')
# ('HDDRR', 'W', '2012')
# ('HDDRR', 'W', '2011')
# ('HDDRR', 'W', '2010')
# ('HDDRR', 'B', '2017')
# ('HDDRR', 'B', '2016')
# ('HDDRR', 'B', '2014')
# ('HDDRR', 'B', '2013')
# ('HDDRR', 'B', '2012')
# ('HDDRR', 'B', '2011')
# ('HDDRR', 'B', '2010')
# ('HDDRR', 'AP', '2017')
# ('HDDRR', 'AP', '2016')
# ('HDDRR', 'AP', '2014')
# ('HDDRR', 'AP', '2013')
# ('HDDRR', 'AP', '2012')
# ('HDDRR', 'AP', '2011')
# ('HDDRR', 'AP', '2010')
# ('HDDRR', 'H', '2017')
# ('HDDRR', 'H', '2016')
# ('HDDRR', 'H', '2014')
# ('HDDRR', 'H', '2013')
# ('HDDRR', 'H', '2012')
# ('HDDRR', 'H', '2011')
# ('HDDRR', 'H', '2010')
# ('HDDRR', 'C', '2017')
# ('HDDRR', 'C', '2016')
# ('HDDRR', 'C', '2014')
# ('HDDRR', 'C', '2013')
# ('HDDRR', 'C', '2012')
# ('HDDRR', 'C', '2011')
# ('HDDRR', 'C', '2010')
# ('HDDRR', 'G', '2017')
# ('HDDRR', 'G', '2016')
# ('HDDRR', 'G', '2014')
# ('HDDRR', 'G', '2013')
# ('HDDRR', 'G', '2012')
# ('HDDRR', 'G', '2011')
# ('HDDRR', 'G', '2010')
# ('HDDRR', 'K', '2017')
# ('HDDRR', 'K', '2016')
# ('HDDRR', 'K', '2014')
# ('HDDRR', 'K', '2013')
# ('HDDRR', 'K', '2012')
# ('HDDRR', 'K', '2011')
# ('HDDRR', 'K', '2010')
# ('HDDRR', 'N', '2017')
# ('HDDRR', 'N', '2016')
# ('HDDRR', 'N', '2014')
# ('HDDRR', 'N', '2013')
# ('HDDRR', 'N', '2012')
# ('HDDRR', 'N', '2011')
# ('HDDRR', 'N', '2010')
# ('HDDRR', 'S', '2017')
# ('HDDRR', 'S', '2016')
# ('HDDRR', 'S', '2014')
# ('HDDRR', 'S', '2013')
# ('HDDRR', 'S', '2012')
# ('HDDRR', 'S', '2011')
# ('HDDRR', 'S', '2010')
# ('YRDEP', '', '2021')
# ('YRDEP', '', '2019')
# ('YRDEP', '', '2017')
# ('YRDEP', '', '2013')
# ('YRDEP', '', '2011')
# ('YRDEP', '', '2009')
# ('YRDEP', '', '2007')
# ('YRDEP', '', '2005')
# ('YRDEP', '', '2003')
# ('YRDEP', '', '2001')
# ('YRDEP', 'F', '2021')
# ('YRDEP', 'F', '2019')
# ('YRDEP', 'F', '2017')
# ('YRDEP', 'F', '2013')
# ('YRDEP', 'F', '2011')
# ('YRDEP', 'F', '2009')
# ('YRDEP', 'F', '2007')
# ('YRDEP', 'F', '2005')
# ('YRDEP', 'F', '2003')
# ('YRDEP', 'F', '2001')
# ('YRDEP', 'M', '2021')
# ('YRDEP', 'M', '2019')
# ('YRDEP', 'M', '2017')
# ('YRDEP', 'M', '2013')
# ('YRDEP', 'M', '2011')
# ('YRDEP', 'M', '2009')
# ('YRDEP', 'M', '2007')
# ('YRDEP', 'M', '2005')
# ('YRDEP', 'M', '2003')
# ('YRDEP', 'M', '2001')
# ('YRDEP', 'W', '2021')
# ('YRDEP', 'W', '2019')
# ('YRDEP', 'W', '2017')
# ('YRDEP', 'W', '2013')
# ('YRDEP', 'W', '2011')
# ('YRDEP', 'W', '2009')
# ('YRDEP', 'W', '2007')
# ('YRDEP', 'W', '2005')
# ('YRDEP', 'W', '2003')
# ('YRDEP', 'W', '2001')
# ('YRDEP', 'B', '2021')
# ('YRDEP', 'B', '2019')
# ('YRDEP', 'B', '2017')
# ('YRDEP', 'B', '2013')
# ('YRDEP', 'B', '2011')
# ('YRDEP', 'B', '2009')
# ('YRDEP', 'B', '2007')
# ('YRDEP', 'B', '2005')
# ('YRDEP', 'B', '2003')
# ('YRDEP', 'B', '2001')
# ('YRDEP', 'A', '2021')
# ('YRDEP', 'AP', '2021')
# ('YRDEP', 'AP', '2019')
# ('YRDEP', 'AP', '2017')
# ('YRDEP', 'AP', '2013')
# ('YRDEP', 'AP', '2011')
# ('YRDEP', 'AP', '2009')
# ('YRDEP', 'AP', '2007')
# ('YRDEP', 'AP', '2005')
# ('YRDEP', 'AP', '2003')
# ('YRDEP', 'AP', '2001')
# ('YRDEP', 'H', '2021')
# ('YRDEP', 'H', '2019')
# ('YRDEP', 'H', '2017')
# ('YRDEP', 'H', '2013')
# ('YRDEP', 'H', '2011')
# ('YRDEP', 'H', '2009')
# ('YRDEP', 'H', '2007')
# ('YRDEP', 'H', '2005')
# ('YRDEP', 'H', '2003')
# ('YRDEP', 'H', '2001')
# ('YRDEP', 'GEN1', '2021')
# ('YRDEP', 'TRA3', '2021')
# ('YRDEP', 'E', '2021')
# ('YRDEP', 'E', '2019')
# ('YRDEP', 'E', '2017')
# ('YRDEP', 'E', '2013')
# ('YRDEP', 'E', '2011')
# ('YRDEP', 'E', '2009')
# ('YRDEP', 'E', '2007')
# ('YRDEP', 'E', '2005')
# ('YRDEP', 'E', '2003')
# ('YRDEP', 'L', '2021')
# ('YRDEP', 'L', '2019')
# ('YRDEP', 'L', '2017')
# ('YRDEP', 'L', '2013')
# ('YRDEP', 'L', '2011')
# ('YRDEP', 'L', '2009')
# ('YRDEP', 'L', '2007')
# ('YRDEP', 'L', '2005')
# ('YRDEP', 'L', '2003')
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File C:\Anaconda\envs\tfm1\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\Anaconda\envs\tfm1\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\Anaconda\envs\tfm1\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File C:\Anaconda\envs\tfm1\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[2], line 14
#      11 res = requests.get(f'https://chicagohealthatlas.org/api/v1/coverage/{topic}')
#      13 # iterate over available data for topic
# ---> 14 for i in range(len(res.json()['coverages']['place'])):
#      16     try:
#      17         # available population groups
#      18         pop = res.json()['coverages']['place'][i]['population']
#
# File C:\Anaconda\envs\tfm1\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests
import pandas as pd

res = requests.get('https://data.cityofchicago.org/resource/vcv6-95ym.json')
clinics = pd.DataFrame(res.json())
clinics.to_csv('clinics.csv',index=False)

# %%
res = requests.get('https://data.cityofchicago.org/resource/crimes.json')

# %%
res
# Out:
# <Response [200]>

# %%
output = []
crime_url = 'https://data.cityofchicago.org/resource/crimes.json'

for _ in range(20):
    offset = 0
    res = requests.get(f'{crime_url}?$limit=50000&$offset={offset}&')
    print(res.status_code) 
    try:
        output.append(pd.DataFrame(res.json()))
        offset += 50_000
        time.sleep(1)
    except:
        pass
crime = pd.concat(output,axis = 0)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
crime['date'].sort_values()
# Out:
# 49999    2023-01-25T06:00:00.000
# 49999    2023-01-25T06:00:00.000
# 49998    2023-01-25T06:00:00.000
# 49999    2023-01-25T06:00:00.000
# 49998    2023-01-25T06:00:00.000
#                   ...
# 0        2023-04-12T23:59:00.000
# 0        2023-04-12T23:59:00.000
# 0        2023-04-12T23:59:00.000
# 0        2023-04-12T23:59:00.000
# 0        2023-04-12T23:59:00.000
# Name: date, Length: 1000000, dtype: object

# %%
crime.to_csv('crime.csv',index=False)

# %%
aaa
