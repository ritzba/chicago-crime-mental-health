# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import glob
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
# path = './data/data_csv_files'
# csv_files = glob.glob(path + "/*.csv")

# %%
# df_list = (pd.read_csv(file) for file in csv_files)

# %%
path = r'"C:\Users\HyeOL\OneDrive - CUNY (1)\GitHub\project_4\chicago_mh\data"' 
# all_files = glob.glob(os.path.join(path , "/*.csv"))

# %%
# %who_ls DataFrame
# Out:
# []

# %% [markdown]
# UNS = uninsured rate CZA = agg ass CZB = burg CZD = drugs CZH = homicide CZL = theft CZM = maj crime CZO = arson CZP = prop crime CZR = robb CZS = sex CZT = mv theft CZU = pub crime CZV = violent HCSNVP = neighborhood violence rate
#
# EMSOD = opioid OD HCSBHP = mh treat rate HCSSPDP = psych distress rate MEODR = opiod OD mortality rate
#
# DIV = cognitive difficulty HCSBDP = binge drinking rate HSCOPP = opiate abuse rate
#
# VRALR = alcohol mortality rate VRDIDR = drug induced mortality rate VRDOR = drug OD mortality rate VRSUR = suicide mortality rate
#
# VFFIR = firearm homicide rate VRHOR = firearm mortality rate

# %%
clinics = pd.read_csv('data/clinics.csv')
crime = pd.read_csv('data/crime.csv')
disp = pd.read_csv('data/disp.csv')
div = pd.read_csv('data/div.csv')
init = pd.read_csv('data/init.csv')
intake = pd.read_csv('data/intake.csv')
sent = pd.read_csv('data/sent.csv')
CZA = pd.read_csv('data/CZA.csv')
CZB = pd.read_csv('data/CZB.csv')
CZD = pd.read_csv('data/CZD.csv')
CZH = pd.read_csv('data/CZH.csv')
CZL = pd.read_csv('data/CZL.csv')
CZM = pd.read_csv('data/CZM.csv')
CZO = pd.read_csv('data/CZO.csv')
CZP = pd.read_csv('data/CZP.csv')
CZR = pd.read_csv('data/CZR.csv')
CZS = pd.read_csv('data/CZS.csv')
CZT = pd.read_csv('data/CZT.csv')
CZU = pd.read_csv('data/CZU.csv')
CZV = pd.read_csv('data/CZV.csv')
EMSOD = pd.read_csv('data/EMSOD.csv')
HCSBDP = pd.read_csv('data/HCSBDP.csv')
HCSBHP = pd.read_csv('data/HCSBHP.csv')
HCSNVP = pd.read_csv('data/HCSNVP.csv')
HCSSPDP = pd.read_csv('data/HCSSPDP.csv')
HDBHR = pd.read_csv('data/HDBHR.csv')
HDDRR = pd.read_csv('data/HDDRR.csv')
HDSZR = pd.read_csv('data/HDSZR.csv')
UNS = pd.read_csv('data/UNS.csv')
YRDEP = pd.read_csv('data/YRDEP.csv')
# Out:
# C:\Users\HyeOL\AppData\Local\Temp\ipykernel_4000\2543441195.py:3: DtypeWarning: Columns (10,11,14,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   disp = pd.read_csv('data/disp.csv')
# C:\Users\HyeOL\AppData\Local\Temp\ipykernel_4000\2543441195.py:5: DtypeWarning: Columns (9,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   init = pd.read_csv('data/init.csv')
# C:\Users\HyeOL\AppData\Local\Temp\ipykernel_4000\2543441195.py:7: DtypeWarning: Columns (10,11,14,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   sent = pd.read_csv('data/sent.csv')

# %%
CZA.head()
# Out:
#    se      g    l    a   p          d          v
# 0 NaN  60601  zip  CZA NaN  2018-2022  66.454485
# 1 NaN  60602  zip  CZA NaN  2018-2022  11.133545
# 2 NaN  60603  zip  CZA NaN  2018-2022  10.292674
# 3 NaN  60604  zip  CZA NaN  2018-2022   7.319068
# 4 NaN  60606  zip  CZA NaN  2018-2022  22.908756

# %%
fig, ax = plt.subplots()
sns.histplot(CZA['v'], ax=ax)  
ax.set_xlim(0,1500)
plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(CZB['v'], ax=ax)  
ax.set_xlim(0,1500)

plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(CZD['v'], ax=ax)  
ax.set_xlim(0,1500)

plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(CZH['v'], ax=ax)  
ax.set_xlim(0,100)

plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(CZL['v'], ax=ax)  
ax.set_xlim(0,3000)

plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(CZM['v'], ax=ax)  
ax.set_xlim(0,5000)

plt.show()
