# %%
import pandas as pd
from sqlalchemy import inspect, create_engine

# %%
url = 'localhost'
port = 5432
user = 'postgres'
pswd = 'postgres'
db = 'project4'

# %%
connection_string = f'postgresql://{user}:{pswd}@{url}:{port}/{db}'

engine = create_engine(connection_string,
                       echo=False)        

engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/project4)

# %%
insp = inspect(engine)

# %%
insp.get_table_names()
# Out:
# ['data_div',
#  'clinics',
#  'crimes',
#  'hcsbdp',
#  'div',
#  'disp',
#  'hcsbhp',
#  'hddrr',
#  'hdszr',
#  'init',
#  'intake',
#  'sent']

# %%
conn = engine.connect()

# %%
conn.execute("SELECT * FROM crimes;")

# %%
conn.execute("SELECT * FROM clinics;")

# %%
conn.execute("SELECT * FROM HCSBHP;")

# %%
conn.execute("SELECT * FROM HDDRR;")

# %%
conn.execute("SELECT * FROM HDSZR;")

# %%
pd.DataFrame(insp.get_columns('crimes'))
# Out:
#                          name     type  nullable default  autoincrement  \
# 0                          id  INTEGER     False    None          False
# 1                 case_number  VARCHAR      True    None          False
# 2                        date     DATE      True    None          False
# 3                       block  VARCHAR      True    None          False
# 4                        iucr  VARCHAR      True    None          False
# 5                primary_type  VARCHAR      True    None          False
# 6                 description  VARCHAR      True    None          False
# 7        location_description  VARCHAR      True    None          False
# 8                      arrest  BOOLEAN      True    None          False
# 9                    domestic  BOOLEAN      True    None          False
# 10                       beat  INTEGER      True    None          False
# 11                   district  INTEGER      True    None          False
# ...

# %%
pd.DataFrame(insp.get_columns('clinics'))
# Out:
#                                                  name     type  nullable  \
# 0                                        organization  VARCHAR      True
# 1                                           site_name  VARCHAR      True
# 2                                           site_type  VARCHAR      True
# 3                                             address  VARCHAR      True
# 4                                                 zip  VARCHAR      True
# 5                                          main_phone  VARCHAR      True
# 6                               service_request_phone  VARCHAR      True
# 7                          evening_hours_availability  BOOLEAN      True
# 8                                evening_hours_detail  VARCHAR      True
# 9                          weekend_hours_availability  BOOLEAN      True
# 10                                          ticc_site  VARCHAR      True
# 11                         all_community_areas_served  VARCHAR      True
# ...

# %%
pd.DataFrame(insp.get_columns('HCSBHP')) #Please let me know why error occurs here.
# Out:
# ---------------------------------------------------------------------------
# NoSuchTableError                          Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 pd.DataFrame(insp.get_columns('HCSBHP'))
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py:497, in Inspector.get_columns(self, table_name, schema, **kw)
#     443 """Return information about columns in `table_name`.
#     444
#     445 Given a string `table_name` and an optional string `schema`, return
#    (...)
#     493
#     494 """
#     496 with self._operation_context() as conn:
# --> 497     col_defs = self.dialect.get_columns(
#     498         conn, table_name, schema, info_cache=self.info_cache, **kw
#     499     )
#     500 for col_def in col_defs:
#     501     # make this easy and only return instances for coltype
#     502     coltype = col_def["type"]
#
# File <string>:2, in get_columns(self, connection, table_name, schema, **kw)
#
# ...

# %%
pd.DataFrame(insp.get_columns('HDDRR'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchTableError                          Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pd.DataFrame(insp.get_columns('HDDRR'))
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py:497, in Inspector.get_columns(self, table_name, schema, **kw)
#     443 """Return information about columns in `table_name`.
#     444
#     445 Given a string `table_name` and an optional string `schema`, return
#    (...)
#     493
#     494 """
#     496 with self._operation_context() as conn:
# --> 497     col_defs = self.dialect.get_columns(
#     498         conn, table_name, schema, info_cache=self.info_cache, **kw
#     499     )
#     500 for col_def in col_defs:
#     501     # make this easy and only return instances for coltype
#     502     coltype = col_def["type"]
#
# File <string>:2, in get_columns(self, connection, table_name, schema, **kw)
#
# ...

# %%
pd.DataFrame(insp.get_columns('HDSZR'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchTableError                          Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 pd.DataFrame(insp.get_columns('HDSZR'))
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py:497, in Inspector.get_columns(self, table_name, schema, **kw)
#     443 """Return information about columns in `table_name`.
#     444
#     445 Given a string `table_name` and an optional string `schema`, return
#    (...)
#     493
#     494 """
#     496 with self._operation_context() as conn:
# --> 497     col_defs = self.dialect.get_columns(
#     498         conn, table_name, schema, info_cache=self.info_cache, **kw
#     499     )
#     500 for col_def in col_defs:
#     501     # make this easy and only return instances for coltype
#     502     coltype = col_def["type"]
#
# File <string>:2, in get_columns(self, connection, table_name, schema, **kw)
#
# ...

# %%
#convert it to a dataframe #crime data needs to be re-copied
crimes = pd.DataFrame(conn.execute("SELECT * FROM crimes;"))
crimes.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sql = """
SELECT *
FROM clinics;
"""

pd.read_sql(sql, engine).head()
# Out:
#                       organization                                  site_name  \
# 0              Howard Brown Health               Howard Brown Health 55th St.
# 1  Access Community Health Network  ACCESS Humboldt Park Family Health Center
# 2                        PrimeCare                    Northwest Health Center
# 3               Catholic Charities              Catholic Charities- Englewood
# 4                        BUILD inc                                  BUILD inc
#
#                                   site_type                   address    zip  \
# 0  Federally Qualified Health Center (FQHC)           1525 E 55th St.  60637
# 1  Federally Qualified Health Center (FQHC)         3202 W. North Ave  60647
# 2  Federally Qualified Health Center (FQHC)   1649 North Pulaski Road  60639
# 3     Community Mental Health Center (CMHC)  6202 S. Halsted, Chicago  60621
# 4        Community Based Organization (CBO)          5100 w. Harrison  60651
#
# ...

# %%
clinics = conn.execute("SELECT * FROM clinics;")
clinics.head() #what is wring here?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 clinics = conn.execute("SELECT * FROM clinics;")
# ----> 2 clinics.head()
#
# AttributeError: 'LegacyCursorResult' object has no attribute 'head'

# %%
sql = """
SELECT *
FROM HCSBHP;
"""

pd.read_sql(sql, engine).head()
# Out:
#           se           g             l       a     p          d          v
# 0   9.118220   1714000-4  neighborhood  HCSBHP  None  2021-2022  84.429441
# 1  17.211785  1714000-40  neighborhood  HCSBHP  None  2021-2022  62.397379
# 2  15.910922  1714000-41  neighborhood  HCSBHP  None  2021-2022  82.894954
# 3  16.159595  1714000-42  neighborhood  HCSBHP  None  2021-2022  82.165229
# 4  14.139089   1714000-1  neighborhood  HCSBHP  None  2021-2022  49.811887

# %%
sql = """
SELECT *
FROM HDDRR;
"""

pd.read_sql(sql, engine).head()
# Out:
#          se      g    l      a     p     d      v
# 0  4.846939  60607  zip  HDDRR  None  2017   44.9
# 1  1.785714  60608  zip  HDDRR  None  2017   23.9
# 2  2.551020  60609  zip  HDDRR  None  2017   35.5
# 3  6.275510  60612  zip  HDDRR  None  2017  115.4
# 4  1.505102  60616  zip  HDDRR  None  2017   12.0

# %%
sql = """
SELECT *
FROM HDSZR;
"""

pd.read_sql(sql, engine).head()
# Out:
#           se      g    l      a     p     d      v
# 0   4.234694  60601  zip  HDSZR  None  2017   16.7
# 1  18.571429  60606  zip  HDSZR  None  2017   80.8
# 2   7.678571  60607  zip  HDSZR  None  2017  106.6
# 3   1.913265  60608  zip  HDSZR  None  2017   28.5
# 4   2.678571  60609  zip  HDSZR  None  2017   42.7
